# %%
# Install any required packages for Gemini integration
! pip install openai

# %%
import os
# import Gemini SDK if specific package exists
# import gemini

# %%
# Set your Gemini API key as environment variable (or directly here, not recommended for public notebooks)
os.environ['GEMINI_API_KEY'] = 'AIzaSyCTCgvXMFL8enBd-hX3SfbkZ1_6WYt34mI'

# Example if Gemini SDK requires initialization
# client = gemini.Client(api_key=os.environ['GEMINI_API_KEY'])

# %%
def ask_gemini(prompt):
    """
    Sends a prompt to Gemini LLM and returns the response
    """
    # Example using hypothetical Gemini API
    # response = client.complete(prompt=prompt, model='gemini-1')
    # return response.text

    # Placeholder until Gemini SDK/API specifics are confirmed
    return "Gemini API response placeholder"

# %%
prompt = "List 5 most in-demand skills for AI internships in 2025."
response = ask_gemini(prompt)
print(response)

# %%
{
 "cells": [
  {
   "cell_type": "markdown",
   "metadata": {},
   "source": [
    "# Gemini LLM Integration for Hack Proj\n",
    "This notebook demonstrates how to integrate Gemini LLM into the hack proj pipeline to get responses based on prompts."
   ]
  },
  {
   "cell_type": "code",
   "metadata": {},
   "source": [
    "# Install required packages\n",
    "!pip install requests"
   ]
  },
  {
   "cell_type": "code",
   "metadata": {},
   "source": [
    "import os\n",
    "import requests"
   ]
  },
  {
   "cell_type": "code",
   "metadata": {},
   "source": [
    "# Set your Gemini API key\n",
    "os.environ['GEMINI_API_KEY'] = 'AIzaSyCTCgvXMFL8enBd-hX3SfbkZ1_6WYt34mI'  # Replace with your actual API key"
   ]
  },
  {
   "cell_type": "code",
   "metadata": {},
   "source": [
    "GEMINI_API_KEY = os.environ.get('GEMINI_API_KEY')\n",
    "GEMINI_API_URL = 'https://api.gemini.ai/v1/complete'  # Hypothetical endpoint"
   ]
  },
  {
   "cell_type": "code",
   "metadata": {},
   "source": [
    "def ask_gemini(prompt, model='gemini-1'):\n",
    "    \"\"\"\n",
    "    Sends a prompt to Gemini LLM and returns the response text.\n",
    "    \"\"\"\n",
    "    headers = {\n",
    "        'Authorization': f'Bearer {GEMINI_API_KEY}',\n",
    "        'Content-Type': 'application/json'\n",
    "    }\n",
    "    payload = {\n",
    "        'model': model,\n",
    "        'prompt': prompt,\n",
    "        'max_tokens': 200\n",
    "    }\n",
    "    response = requests.post(GEMINI_API_URL, json=payload, headers=headers)\n",
    "    if response.status_code == 200:\n",
    "        return response.json().get('text', '')\n",
    "    else:\n",
    "        return f'Error {response.status_code}: {response.text}'"
   ]
  },
  {
   "cell_type": "code",
   "metadata": {},
   "source": [
    "# Test the LLM\n",
    "prompt = 'List 5 most in-demand skills for AI internships in 2025.'\n",
    "response = ask_gemini(prompt)\n",
    "print(response)"
   ]
  },
  {
   "cell_type": "code",
   "metadata": {},
   "source": [
    "# Optional: Integrate with hack proj dataset\n",
    "# import pandas as pd\n",
    "# df = pd.read_csv('internship_dataset.csv')\n",
    "# user_skills = ['Python', 'Machine Learning', 'Data Analysis']\n",
    "# prompt = f'Suggest top 5 internships from this dataset based on skills: {user_skills}'\n",
    "# response = ask_gemini(prompt)\n",
    "# print(response)"
   ]
  }
 ],
 "metadata": {"kernelspec": {"display_name": "Python 3", "language": "python", "name": "python3"}, "language_info": {"name": "python", "version": "3.10"}},
 "nbformat": 4,
 "nbformat_minor": 5
}

# %%
# Install required packages
# !pip install google-genai

import os
from google import genai

# Set your Gemini API key
os.environ['GEMINI_API_KEY'] = 'AIzaSyCTCgvXMFL8enBd-hX3SfbkZ1_6WYt34mI'  # Replace with your actual API key

# Initialize the Gemini client
client = genai.Client()

def ask_gemini(prompt, model="gemini-2.5-flash"):
    """
    Sends a prompt to Gemini LLM and returns the response text.
    """
    response = client.models.generate_content(
        model=model,
        contents=prompt
        
    )
    return response.text

# Test the LLM
prompt = "List 5 most in-demand skills for AI internships in 2025."
response = ask_gemini(prompt)
print(response)

# %%
{
 "cells": [
  {
   "cell_type": "markdown",
   "metadata": {},
   "source": [
    "# Gemini LLM Integration for Hack Proj\n",
    "This notebook demonstrates how to integrate Gemini LLM into the hack proj pipeline to get responses based on prompts and recommend internships based on user skills."
   ]
  },
  {
   "cell_type": "code",
   "metadata": {},
   "source": [
    "# Install required packages\n",
    "!pip install google-genai pandas"
   ]
  },
  {
   "cell_type": "code",
   "metadata": {},
   "source": [
    "import os\n",
    "import pandas as pd\n",
    "from google import genai"
   ]
  },
  {
   "cell_type": "code",
   "metadata": {},
   "source": [
    "# Set your Gemini API key\n",
    "os.environ['GEMINI_API_KEY'] = 'your_api_key_herAIzaSyCTCgvXMFL8enBd-hX3SfbkZ1_6WYt34mI'  # Replace with your actual API key\n",
    "client = genai.Client()"]
  },
  {
   "cell_type": "code",
   "metadata": {},
   "source": [
    "def ask_gemini(prompt, model='gemini-2.5-flash'):\n",
    "    \"\"\"Sends a prompt to Gemini LLM and returns the response text.\"\"\"\n",
    "    response = client.models.generate_content(model=model, contents=prompt)\n",
    "    return response.text"]
  },
  {
   "cell_type": "code",
   "metadata": {},
   "source": [
    "# Load your internship dataset\n",
    "df = pd.read_csv('D:\project hack\data\raw\internship_data.csv')  # Replace with your actual dataset path\n",
    "df.head()"]
  },
  {
   "cell_type": "code",
   "metadata": {},
   "source": [
    "# User input skills\n",
    "user_skills = ['Python', 'Machine Learning', 'SQL']  # Example skills"]
  },
  {
   "cell_type": "code",
   "metadata": {},
   "source": [
    "# Prepare dataset summary for Gemini\n",
    "dataset_summary = df.head(50).to_dict(orient='records')  # Summarize top 50 rows for prompt\n",
    "prompt = f'Suggest top 5 internships from this dataset that match these skills: {user_skills}. Here is the dataset sample: {dataset_summary}'"]
  },
  {
   "cell_type": "code",
   "metadata": {},
   "source": [
    "# Ask Gemini for recommendations\n",
    "response = ask_gemini(prompt)\n",
    "print(response)"]
  }
 ],
 "metadata": {"kernelspec": {"display_name": "Python 3", "language": "python", "name": "python3"}, "language_info": {"name": "python", "version": "3.10"}},
 "nbformat": 4,
 "nbformat_minor": 5
}

# %%
{'cells': [{'cell_type': 'markdown', 'metadata': {}, 'source': ['# Gemini LLM Integration for Hack Proj\nThis notebook demonstrates how to integrate Gemini LLM into the hack proj pipeline to get responses based on prompts and recommend internships based on user skills.']}, {'cell_type': 'code', 'metadata': {}, 'source': ['# Install required packages\n!pip install google-genai pandas']}, {'cell_type': 'code', 'metadata': {}, 'source': ['import os\nimport pandas as pd\nfrom google import genai']}, {'cell_type': 'code', 'metadata': {}, 'source': ['# Set your Gemini API key\nos.environ["GEMINI_API_KEY"] = "your_api_key_here"  # Replace with your actual API key\nclient = genai.Client()']}, {'cell_type': 'code', 'metadata': {}, 'source': ['def ask_gemini(prompt, model="gemini-2.5-flash"):\n    """Sends a prompt to Gemini LLM and returns the response text."""\n    response = client.models.generate_content(model=model, contents=prompt)\n    return response.text']}, {'cell_type': 'code', 'metadata': {}, 'source': ['# Load your internship dataset\ndf = pd.read_csv("internship_dataset.csv")  # Replace with your actual dataset path\ndf.head()']}, {'cell_type': 'code', 'metadata': {}, 'source': ['# User input skills\nuser_skills = ["Python", "Machine Learning", "SQL"]  # Example skills']}, {'cell_type': 'code', 'metadata': {}, 'source': ['# Prepare dataset summary for Gemini\ndataset_summary = df.head(50).to_dict(orient="records")  # Summarize top 50 rows for prompt\nprompt = f"Suggest top 5 internships from this dataset that match these skills: {user_skills}. Here is the dataset sample: {dataset_summary}"']}, {'cell_type': 'code', 'metadata': {}, 'source': ['# Ask Gemini for recommendations\nresponse = ask_gemini(prompt)\n\n# Format Gemini output as a clean numbered list\nrecommendations = [rec.strip() for rec in response.split("\n") if rec.strip()]  # Remove empty lines\nfor i, rec in enumerate(recommendations, 1):\n    print(f"{i}. {rec}")']}], 'metadata': {'kernelspec': {'display_name': 'Python 3', 'language': 'python', 'name': 'python3'}, 'language_info': {'name': 'python', 'version': '3.10'}}, 'nbformat': 4, 'nbformat_minor': 5}

# %%
# Install required packages
# !pip install google-genai pandas

# %%
import os
import pandas as pd
from google import genai

# %%
# Set your Gemini API key directly (faster)
GEMINI_API_KEY = "AIzaSyCTCgvXMFL8enBd-hX3SfbkZ1_6WYt34mI"  # Replace with your real key
os.environ['GEMINI_API_KEY'] = GEMINI_API_KEY
client = genai.Client()

# %%
def ask_gemini(prompt, model='gemini-2.5-flash'):
    """Sends a prompt to Gemini LLM and returns the response text."""
    response = client.models.generate_content(model=model, contents=prompt)
    return response.text

# %%
# Take dataset path as input
dataset_path = r"D:\project hack\data\raw\internship_data.csv"
df = pd.read_csv(dataset_path)
df.head()
# Out:
#    Internship Id                                        Role  \
# 0        2456465     Business Development (Sales) Internship
# 1        2456478             Human Resources (HR) Internship
# 2        2452185  Content & E-Commerce Management Internship
# 3        2450936               Project Management Internship
# 4        2450882                Digital Marketing Internship
#
#                                        Company Name  \
# 0                        Madbrains Technologies LLP
# 1                    Jobs Flash Consulting Services
# 2                                    Fall For Flora
# 3  Special Situation Advisors India Private Limited
# 4  Special Situation Advisors India Private Limited
#
#                                          Location  Duration  \
# 0                         ('Chandigarh, Mohali',)  4 Months
# 1                                    ('Gurgaon',)  6 Months
# 2           ('Faridabad, Delhi, Gurgaon, Noida',)  4 Months
# ...

# %% [markdown]
# none

# %%
# User input skills
user_skills = input("Enter your skills separated by commas: ").split(',')
user_skills = [skill.strip() for skill in user_skills]
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[6], line 2
#       1 # User input skills
# ----> 2 user_skills = input("Enter your skills separated by commas: ").split(',')
#       3 user_skills = [skill.strip() for skill in user_skills]
#
# File c:\Users\jatin\AppData\Local\anaconda3\Lib\site-packages\ipykernel\kernelbase.py:1262, in Kernel.raw_input(self, prompt)
#    1260     msg = "raw_input was called, but this frontend does not support input requests."
#    1261     raise StdinNotImplementedError(msg)
# -> 1262 return self._input_request(
#    1263     str(prompt),
#    1264     self._parent_ident["shell"],
#    1265     self.get_parent("shell"),
#    1266     password=False,
#    1267 )
#
# File c:\Users\jatin\AppData\Local\anaconda3\Lib\site-packages\ipykernel\kernelbase.py:1305, in Kernel._input_request(self, prompt, ident, parent, password)
# ...

# %%
# Prepare dataset summary for Gemini
dataset_summary = df.head(50).to_dict(orient='records')  # Summarize top 50 rows for prompt
prompt = f"Suggest top 5 internships from this dataset that match these skills: {user_skills}. Here is the dataset sample: {dataset_summary}"
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[7], line 3
#       1 # Prepare dataset summary for Gemini
#       2 dataset_summary = df.head(50).to_dict(orient='records')  # Summarize top 50 rows for prompt
# ----> 3 prompt = f"Suggest top 5 internships from this dataset that match these skills: {user_skills}. Here is the dataset sample: {dataset_summary}"
#
# NameError: name 'user_skills' is not defined

# %%
# If you have a string of skills separated by commas
skills_input = "python,ml,webdev"

# Convert to a clean list
user_skills = [skill.strip() for skill in skills_input.split(",")]

print(user_skills)
# Output: ['python', 'ml', 'webdev']
# Out:
# ['python', 'ml', 'webdev']

# %%
dataset_summary = df.head(50).to_dict(orient='records')  # Summarize top 50 rows for prompt

# %%
dataset_summary = df.head(10).to_dict(orient='records')
