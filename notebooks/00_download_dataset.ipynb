# %%
import kagglehub

# Download latest version
path = kagglehub.dataset_download("vipul143/internshala-internship-dataset")

print("Path to dataset files:", path)
# Out:
# ...
# Path to dataset files: C:\Users\jatin\.cache\kagglehub\datasets\vipul143\internshala-internship-dataset\versions\1

# %%
import pandas as pd
import os

# Path to the CSV inside KaggleHub cache
csv_path = r"C:/Users/jatin/.cache/kagglehub/datasets/vipul143/internshala-internship-dataset/versions/1/Internshala_dataset.csv"

# Verify file exists
if not os.path.exists(csv_path):
    raise FileNotFoundError(f"CSV not found at {csv_path}")

# Load dataset
df = pd.read_csv(csv_path)

print("✅ Dataset loaded successfully!")
print("Shape:", df.shape)
df.head()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[15], line 9
#       7 # Verify file exists
#       8 if not os.path.exists(csv_path):
# ----> 9     raise FileNotFoundError(f"CSV not found at {csv_path}")
#      11 # Load dataset
#      12 df = pd.read_csv(csv_path)
#
# FileNotFoundError: CSV not found at C:/Users/jatin/.cache/kagglehub/datasets/vipul143/internshala-internship-dataset/versions/1/Internshala_dataset.csv
